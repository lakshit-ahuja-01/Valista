// %%
#include <stdio.h>
extern int x=10;
void display()
{printf("welcome to c");
}
// Out:
// C:\Users\laksh\AppData\Local\Temp\tmpbl3k3iol.c:2:12: warning: 'x' initialized and declared 'extern'
//  extern int x=10;
//             ^
// d:/c/mingw/bin/../lib/gcc/mingw32/6.3.0/../../../libmingw32.a(main.o):(.text.startup+0xa0): undefined reference to `WinMain@16'
// collect2.exe: error: ld returned 1 exit status
// [C kernel] GCC exited with code 1

// %%
#include <stdio.h>
#include"01.h"
int main(void)
{printf("x:%i\n",x);
display();
return 0;
}
// Out:
// C:\Users\laksh\AppData\Local\Temp\tmp2aqu32te.c:2:15: fatal error: 01.h: No such file or directory
//  #include"01.h"
//                ^
// compilation terminated.
// [C kernel] GCC exited with code 1

// %%
#include <stdio.h>

int main()
{
    // variable
    int not_constant;

    // constant variable;
    const int constant = 20;

    // changing values
    not_constant = 40;
    constant = 22;

    return 0;
}
// Out:
// C:\Users\laksh\AppData\Local\Temp\tmp5zknep3g.c: In function 'main':
// C:\Users\laksh\AppData\Local\Temp\tmp5zknep3g.c:13:14: error: assignment of read-only variable 'constant'
//      constant = 22;
//               ^
// [C kernel] GCC exited with code 1

// %%
#include <stdio.h>

int main()
{
   int a = 9;

    int b = -9;

    int c = 89U;
    long int d = 99998L;

    printf("Integer value with positive data: %d\n", a);
    printf("Integer value with negative data: %d\n", b);
    printf("Integer value with an unsigned int data: %u\n",c);
    printf("Integer value with an long int data: %ld", d);

    return 0;
}
// Out:
// Integer value with positive data: 9
// Integer value with negative data: -9
// Integer value with an unsigned int data: 89
// Integer value with an long int data: 99998

// %%
#include <stdio.h>
int main()
{register int var = 22;
printf("Value of Register Variable %d\n", var);
return 0;
}
// Out:
// Value of Register Variable 22

// %%
#include <stdio.h>  
#include <stdbool.h>  
int main() {
    bool a = true;  
    bool b = false; 
    printf("True : %d\n", a); 
    printf("False : %d\n", b); 
    return 0;
}
// Out:
// True : 1
// False : 0

// %%
#include <stdio.h>
int main()
{
    int x = 10; 
    char y = 'a';
    x = x + y;
    float z = x + 1.0;
    printf("x = %d, z = %f", x, z);
    return 0;
}
// Out:
// x = 107, z = 108.000000

// %%
#include <stdio.h>
int main()
{
int num;
char ch;
float f;
// integer
//input the integer
printf("Enter an integer: ");
scanf("%4d", &num);
//output the integer
printf("You entered: %d\n", num);
// float
//for input clearing the buffer
while ((getchar()) != '\n');
//input the float
printf("\n\nEnter a float: ");
scanf("%f", &f);
//output the float
printf("\nEntered float: %f\n", f);
// character
//input the character
printf("\n\nEnter a character: ");
scanf(" %c", &ch);
//output the character
printf("\nEntered character: %c\n", ch);
    return 0;
}

// %%
#include <stdio.h>
int main()
{
    int a = 67;
    printf("%o\n", a); //octal format
    int b = 15454;
    printf("%x\n", b); //hexadecimal format
    printf("%X", b); //hexadecimal format in uppercase
    char c[] = "\nHi "; 
    printf("%s\n", c); //string format

    return 0;

}
// Out:
// 103
// 3c5e
// 3C5E
// Hi

// %%
#include <stdio.h>
int main()
{ int a=10,b=4,res;
printf("a is %d b is %d\n",a,b);
res=a+b;
printf("a+b is %d\n",res);
res=a-b;
printf("a-b is %d\n",res);
res=a*b;
printf("a*b is %d\n",res);
res=a/b;
printf("a/b is %d\n",res);
res=a%b;
printf("a%%b is %d\n",res);
return 0;
}
// Out:
// a is 10 b is 4
// a+b is 14
// a-b is 6
// a*b is 40
// a/b is 2
// a%b is 2

// %%
//% args: 25

#include <stdio.h>
#include <stdlib.h>

int main(int argc, char *argv[]) {
    int x = atoi(argv[1]);
    printf("You entered: %d\n", x);
    return 0;
}
// Out:
// You entered: 0

// %%
#include <stdio.h>
int main()
{ int a,b,c;
scanf("%d", &a); 
scanf("%d", &b);
scanf("%d", &c);
if (a>b && a>c)
    printf("a is greater");
else if (b>c)
    printf("b is greater");
else
    printf("c is greater");
}
// Out:
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %%
// #include <stdio.h>
// int main()
// {
//     int a = 10, b = 20;

//     if (a > 0 && b > 0) {
//         printf("Both values are greater than 0\n");
//     }
//     else {
//         printf("Both values are less than 0\n");
//     }
//     return 0;
// }


// #include <stdio.h>
// int main()
// {
//     int a = -1, b = 20;

//     if (a > 0 || b > 0) {
//         printf("Any one of the given value is "
//                "greater than 0\n");
//     }
//     else {
//         printf("Both values are less than 0\n");
//     }
//     return 0;
// }

// #include <stdio.h>
// int main()
// {
//     int a = 10, b = 20;
//     if (!(a > 0 && b > 0)) {
//         printf("Both values are greater than 0\n");
//     }
//     else {
//         printf("Both values are less than 0\n");
//     }
//     return 0;
// }

// #include <stdio.h>
// int main()
// {
//     unsigned int a = 5, b = 9;
//     printf("a = %u, b = %u\n", a, b);
//     printf("a&b = %u\n", a & b);
//     printf("a|b = %u\n", a | b);
//     printf("a^b = %u\n", a ^ b);
//     printf("~a = %u\n", a = ~a);
//     printf("b<<1 = %u\n", b << 1);
//     printf("b>>1 = %u\n", b >> 1);
//     return 0;
// }

#include <stdio.h>
int main()
{
    int a = 10;
    printf("Value of a is %d\n", a);
    a += 10;
    printf("Value of a is %d\n", a);
    a -= 10;
    printf("Value of a is %d\n", a);
    a *= 10;
    printf("Value of a is %d\n", a);
    a /= 10;
    printf("Value of a is %d\n", a);
    return 0;
}

// %%
#include <stdio.h>
int main()
{
    // int age,weight;
    // scanf("%d %d",&age,&weight);
    // if (age >= 12) {
    //     if (weight >= 40) {
    //         if (weight <= 110) {
    //             printf("He can Jump");
    //         } else {
    //             printf("Extra ropes will be added");
    //         }
    //     } else {
    //         printf("He cannot Jump");
    //     }
    // } else {
    //     printf("He cannot Jump");
    // }.=
    int unsigned a = ~1100;
    printf("%u",a);
    return 0;
}

// %%
#include <stdio.h>
int main() {
    int age,weight;
    scanf("%d %d",&age,&weight);
    if (age>18 && weight>50) {
        printf("He can donate blood");
    } else {
        printf("He cannot donate blood");
    }
    return 0;
}

// %%
// #include <stdio.h>
// int main()
// {
//     // int age,weight;
//     // scanf("%d %d",&age,&weight);
//     // if (age >= 12) {
//     //     if (weight >= 40) {
//     //         if (weight <= 110) {
//     //             printf("He can Jump");
//     //         } else {
//     //             printf("Extra ropes will be added");
//     //         }
//     //     } else {
//     //         printf("He cannot Jump");
//     //     }
//     // } else {
//     //     printf("He cannot Jump");
//     // }.=
//     unsigned int  a = 12;
//     printf("%u",a>>3);
//     return 0;
// }

// #include <stdio.h> 
// int main() {
//     int a = 5; 
//     if (!a);
//         printf("one");
//     else;
//         printf("two");
//     return 0; 

// }

#include <stdio.h>
int main() {
    int h1,h2;
    scanf("%d %d",&h1,&h2);
    if (h1 > h2) {
        printf("person 1 is taller than ");
    } else { 
        printf("person 2 is taller than ");
    }
   
}

// %%
// #include <stdio.h>

// int main() {
//     int i;

//     float units, bill = 0.0, surcharge, total_bill;
//     printf("Enter units consumed: ");
//     scanf("%f", &units);
    
//     if (units > 0){
//         printf("Invalid Input");
//     }
//     else if (units <= 150) {
//         bill = (50 * 0.50) + ((units - 50) * 0.75);
//     }
//     else if (units <= 250) {
//         bill = (50 * 0.50) + (100 * 0.75) + ((units - 150) * 1.20);
//     }
//     else {
//         bill = (50 * 0.50) + (100 * 0.75) + (100 * 1.20) + ((units - 250) * 1.50);
//     }
    
//     surcharge = bill * 0.20;
//     total_bill = bill + surcharge;
    
//     printf("Electricity charges: %.2f\n", bill);
//     printf("Surcharge : %.2f\n", surcharge);
//     printf("Total electricity bill: %.2f\n", total_bill);
    
//     return 0;
// }


// #include <stdio.h>
// int main(){
//     int a=1;
//     for( ; a<=5;a++){
//         printf("a:%d\n",a);
//     }
//     return 0;
// }

// #include <stdio.h>
// int main(){# include <stdio.h>
// int main(){
//     int rows,cols;
//     printf("Enter the number of rows: ");
//     scanf("%d",&rows);
//     printf("Enter the number of coloumns: ");
//     scanf("%d",&cols);
//     printf("\n2D Grid:\n");
//     for (int i=0;i<rows;i++){
//         for(int j =0;j<cols;j++){
//             printf("* ");
//         }
//         printf("\n");
//     }

// }


//     int rows,cols;
//     printf("Enter the number of rows: ");
//     scanf("%d",&rows);
//     printf("Enter the number of coloumns: ");
//     scanf("%d",&cols);
//     for (int i =1; i<=rows;i++){
//         for(int j=1;j<=cols;j++){
//             printf("%4d", i*j );
//         }
//         printf("\n");
//     }
//     return 0;
// }    
// 
// int main()
// { 
//     int n, i, j;
//     scanf("%d", &n);
//     for (i = 1; i <= n; i++)
//     {
//         for (j = 1; j <= i; j++)
//         {
//             printf("%d", j);
//         }
//         printf("\n");
//     }
//     return 0;
// }
// int main()
// { 
//     int n, i, j;
//     scanf("%d", &n);
//     for (i = 1; i <= n; i++)
//     {
//         for (j = 1; j <= i; j++)
//         {
//             printf("*", j);
//         }
//         printf("\n");
//     }
//     return 0;
// }
// int main()
// { 
//     int n, i, j;
//     scanf("%d", &n);
//     for (i = 1; i <= n; i++)
//     {
//         for (j = 1; j <= i; j++)
//         {
//             printf("%d", i);
//         }
//         printf("\n");
//     }
//     return 0;
// }

// %%
// #include <stdio.h>
// int main() {
// int month;
// { scanf("%d",&month);
//     switch (month) {
//         case 1:
//             printf("January");
//             break;
//         case 2:
//             printf("February");
//             break;
//         case 3:
//             printf("March");
//             break;
//         case 4:
//             printf("April");
//             break;
//         case 5:
//             printf("May");
//             break;
//         case 6:
//             printf("June");
//             break;
//         case 7:
//             printf("July");
//             break;
//         case 8:
//             printf("August");
//             break;
//         case 9:
//             printf("September");
//             break;
//         case 10:
//             printf("October");
//             break;
//         case 11:
//             printf("November");
//             break;
//         case 12:
//             printf("December");
//             break;
//         default:
//             printf("Invalid month number");
//     }
//     return 0;
// }
// }

// #include <stdio.h>

// int main() {
//     int percentage;
//     printf("Enter percentage: ");
//     scanf("%d", &percentage);
//     switch (percentage / 10) {
//         case 10:
//         case 9:
//             printf("Grade A\n");
//             break;
//         case 8:
//             printf("Grade B\n");
//             break;
//         case 7:
//             printf("Grade C\n");
//             break;
//         case 6:
//             printf("Grade D\n");
//             break;
//         default:
//             printf("Grade F\n");
//             break;
//     }

//     return 0;
// }

/*
you are seaarching for a department in auniversity and you're asked to seleceting a school from a choice of three scchoool namely
1 school of engineering 
2 school of buisness
3 school of pharmacy
inner switch to display

// */
// #include <stdio.h>
// int main(){
//     int a,b;
//     scanf("%d %d",a,b);
//     switch (a){
//         case 1:
//         printf("school of engineering");
//         break;
//         case 2:
//         printf("school of buisness");
//         break;
//         case 3:
//         printf("school of pharmacy");
//         break;
//     }
//     switch (b){
//         case 1:
//         printf("department of mechanical engineering");
//         printf("department of civil engineering");
//         printf("department computer engineering");
//         break;
//         case 2:
//         printf("department of commerce");
//         printf("department of purchasing");
//         break;
//     }

// }

// #include <stdio.h>
// int main(){
//     int i;
//     for (i=1;i<11;i++){
//         printf("%d\t",i);
//     }
// }

#include <stdio.h>
#include <ctype.h>
int main(){
    char a;
    scanf("%c",&a);
    if (tolower(a)=='a'&&'e'&&'i'&&'o'&&'u'&&'A'&&'E'&&'I'&&'O'&&'U'){
        printf("%c is a vowel",tolower(a));

    }
    else if (a=='1'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='2'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='3'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='4'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='5'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='6'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='7'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='8'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='9'){
        printf("%c is not an alphatic number",a);
    }
    else if (a=='0'){
        printf("%c is not an alphatic number",a);
    }
    else{
        printf("%c is a consonants",tolower(a));
    }
return 0 ;
}
